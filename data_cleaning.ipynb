# %%
# Smash Bros Ultimate Frame Data Analysis
# ======================================

# This notebook loads and processes frame data for Super Smash Bros Ultimate
# Based on the SakurAI project structure

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pathlib import Path

# %%
# Set visualization styles
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 8)

# %%
# Define path to data directory
DATA_DIR = "./data"  # Adjust if needed

# %%
# Check if data directory exists
if not os.path.exists(DATA_DIR):
    print(f"Warning: Data directory '{DATA_DIR}' not found")
    
    # Create the directory if it doesn't exist
    os.makedirs(DATA_DIR, exist_ok=True)
    print(f"Created data directory at '{DATA_DIR}'")

# %%
# Function to load and display dataframe info
def load_and_describe_dataframe(file_name):
    """
    Load a CSV file and return a pandas DataFrame.
    Also prints information about the DataFrame.
    
    Args:
        file_name (str): Name of the CSV file in the data directory
        
    Returns:
        pandas.DataFrame: Loaded and processed DataFrame
    """
    file_path = os.path.join(DATA_DIR, file_name)
    
    if not os.path.exists(file_path):
        print(f"Error: File '{file_name}' not found in '{DATA_DIR}'")
        return None
    
    # Load the CSV file
    df = pd.read_csv(file_path)
    
    # Print information about the DataFrame
    print(f"\n{'='*50}")
    print(f"File: {file_name}")
    print(f"Shape: {df.shape[0]} rows x {df.shape[1]} columns")
    print(f"{'='*50}")
    print("\nSample data (first 5 rows):")
    print(df.head())
    print("\nColumn data types:")
    print(df.dtypes)
    print("\nMissing values per column:")
    print(df.isna().sum())
    
    return df

# %%
# Load all dataframes
print("Loading Smash Bros Ultimate frame data...")
# Out:
# Loading Smash Bros Ultimate frame data...

# %%
# Characters dataframe
characters_df = load_and_describe_dataframe("characters.csv")
# Out:
# ==================================================
# File: characters.csv
# Shape: 89 rows x 94 columns
# ==================================================
#
# Sample data (first 5 rows):
#      character_id       file_name hitboxes         name number        value  \
# 0        01_mario        01_mario      NaN        Mario     01        mario
# 1  02_donkey-kong  02_donkey-kong      NaN  Donkey Kong     02  donkey-kong
# 2         03_link         03_link      NaN         Link     03         link
# 3  04e_dark-samus  04e_dark-samus      NaN   Dark Samus    04e   dark-samus
# 4        04_samus        04_samus      NaN        Samus     04        samus
#
#    internal_id attr_completed  attr_id    attr_name  ... param_WallJumpHSpeed  \
# 0          1.0           True      1.0        Mario  ...                  1.3
# 1          2.0           True      2.0  Donkey Kong  ...                  1.3
# 2          3.0           True      3.0         Link  ...                  1.3
# 3          5.0           True      5.0   Dark Samus  ...                  1.3
# 4          4.0           True      4.0        Samus  ...                  1.3
#
#   param_WallJumpVSpeed param_FinalSmashMeterDamageMultiplier  \
# 0                  2.3                                  0.90
# 1                  2.7                                  0.70
# 2                  2.4                                  0.70
# 3                  2.1                                  0.85
# 4                  2.3                                  0.70
#
#   param_FinalSmashMeterKBMultiplier    map_value map_number  map_id  \
# 0                             0.875        mario         01     1.0
# 1                             1.020  donkey-kong         02     2.0
# 2                             1.035         link         03     3.0
# 3                             0.989   dark-samus        04e     5.0
# 4                             1.060        samus         04     4.0
#
#         map_series  map_completed  map_version
# 0      super-mario           True      v13.0.1
# 1      donkey-kong           True      v13.0.1
# 2  legend-of-zelda           True      v13.0.1
# 3          metroid           True      v13.0.1
# 4          metroid           True      v13.0.1
#
# [5 rows x 94 columns]
#
# Column data types:
# character_id      object
# file_name         object
# hitboxes          object
# name              object
# number            object
#                   ...
# map_number        object
# map_id           float64
# map_series        object
# map_completed     object
# map_version       object
# Length: 94, dtype: object
#
# Missing values per column:
# character_id      0
# file_name         0
# hitboxes         88
# name              0
# number            0
#                  ..
# map_number        1
# map_id            1
# map_series        1
# map_completed     1
# map_version       1
# Length: 94, dtype: int64

# %%
# Moves dataframe
moves_df = load_and_describe_dataframe("moves.csv")
# Out:
# ==================================================
# File: moves.csv
# Shape: 3621 rows x 12 columns
# ==================================================
#
# Sample data (first 5 rows):
#   character_id  internal_id  move_index complete  faf  frames grabs hurtboxes  \
# 0     01_mario          1.0           0      NaN   19      19   NaN       NaN
# 1     01_mario          1.0           1      NaN   21      21   NaN       NaN
# 2     01_mario          1.0           2      NaN   33      33   NaN       NaN
# 3     01_mario          1.0           3      NaN   25      25   NaN       NaN
# 4     01_mario          1.0           4      NaN   25      25   NaN       NaN
#
#                 name notes type         value
# 0              Jab 1   NaN  NaN     MarioJab1
# 1              Jab 2   NaN  NaN     MarioJab2
# 2              Jab 3   NaN  NaN     MarioJab3
# 3       Forward Tilt   NaN  NaN    MarioFTilt
# 4  Forward Tilt (Up)   NaN  NaN  MarioFTiltUp
#
# Column data types:
# character_id     object
# internal_id     float64
# move_index        int64
# complete         object
# faf               int64
# frames            int64
# grabs            object
# hurtboxes        object
# name             object
# notes            object
# type             object
# value            object
# dtype: object
#
# Missing values per column:
# character_id       0
# internal_id      202
# move_index         0
# complete        3595
# faf                0
# frames             0
# grabs           3329
# hurtboxes       2647
# name               0
# notes           3571
# type            3620
# value              0
# dtype: int64

# %%
# Hitboxes dataframe
hitboxes_df = load_and_describe_dataframe("hitboxes.csv")
# Out:
# ==================================================
# File: hitboxes.csv
# Shape: 11408 rows x 48 columns
# ==================================================
#
# Sample data (first 5 rows):
#   character_id  internal_id  move_index  hitbox_index move_name absorbable  \
# 0     01_mario          1.0           0             0     Jab 1      False
# 1     01_mario          1.0           0             1     Jab 1      False
# 2     01_mario          1.0           0             2     Jab 1      False
# 3     01_mario          1.0           0             3     Jab 1      False
# 4     01_mario          1.0           1             0     Jab 2      False
#
#    angle   bkb       bone          clang_rebound  ... status trip  \
# 0  361.0  20.0        top  attack_setoff_kind_on  ...    NaN  0.0
# 1  361.0  20.0        top  attack_setoff_kind_on  ...    NaN  0.0
# 2  180.0  15.0        top  attack_setoff_kind_on  ...    NaN  0.0
# 3  361.0  15.0        top  attack_setoff_kind_on  ...    NaN  0.0
# 4  361.0  20.0  shoulderr  attack_setoff_kind_on  ...    NaN  0.0
#
#                   type  unk    x   x2    y   y2     z   z2
# 0  attack_region_punch  NaN  0.0  NaN  6.3  NaN   6.0  NaN
# 1  attack_region_punch  NaN  0.0  NaN  6.3  NaN   8.7  NaN
# 2  attack_region_punch  NaN  0.0  NaN  6.3  NaN  12.0  NaN
# 3  attack_region_punch  NaN  0.0  NaN  6.3  NaN  12.0  NaN
# 4  attack_region_punch  NaN  1.4  NaN  0.0  NaN   0.0  NaN
#
# [5 rows x 48 columns]
#
# Column data types:
# character_id        object
# internal_id        float64
# move_index           int64
# hitbox_index         int64
# move_name           object
# absorbable          object
# angle              float64
# bkb                float64
# bone                object
# clang_rebound       object
# collisionpart       object
# color               object
# damage              object
# direct_hitbox       object
# direct_indirect     object
# disablehitlag       object
# effect              object
# facingrestrict      object
# fkb                float64
# flinchless          object
# frames              object
# friendlyfire        object
# ground_or_air       object
# hitbits             object
# hitlag             float64
# id                  object
# kbg                float64
# kind                object
# notes               object
# part               float64
# reflectable         object
# rehit              float64
# sdi                float64
# setweight           object
# sfxlevel            object
# sfxtype             object
# shielddamage        object
# size               float64
# status              object
# trip               float64
# type                object
# unk                 object
# x                  float64
# x2                  object
# y                  float64
# y2                  object
# z                  float64
# z2                  object
# dtype: object
#
# Missing values per column:
# character_id           0
# internal_id          478
# move_index             0
# hitbox_index           0
# move_name              0
# absorbable            74
# angle                 61
# bkb                   61
# bone                  60
# clang_rebound         74
# collisionpart         74
# color                105
# damage                61
# direct_hitbox        183
# direct_indirect    11299
# disablehitlag         74
# effect                61
# facingrestrict        61
# fkb                   61
# flinchless            74
# frames                 0
# friendlyfire          74
# ground_or_air         60
# hitbits               74
# hitlag                61
# id                    47
# kbg                   61
# kind               11395
# notes              10807
# part                  74
# reflectable           74
# rehit                 74
# sdi                   74
# setweight             74
# sfxlevel              61
# sfxtype               61
# shielddamage          74
# size                  60
# status             11394
# trip                  74
# type                  61
# unk                11395
# x                     60
# x2                  4354
# y                     60
# y2                  4354
# z                     60
# z2                  4355
# dtype: int64

# %%
# Throws dataframe
throws_df = load_and_describe_dataframe("throws.csv")
# Out:
# ==================================================
# File: throws.csv
# Shape: 392 rows x 43 columns
# ==================================================
#
# Sample data (first 5 rows):
#      character_id  internal_id  move_index  throw_index      move_name  \
# 0        01_mario          1.0          24            0  Forward Throw
# 1        01_mario          1.0          25            0     Back Throw
# 2        01_mario          1.0          26            0       Up Throw
# 3        01_mario          1.0          27            0     Down Throw
# 4  02_donkey-kong          2.0          20            0     Back Throw
#
#   absorbable  angle  bkb bone clang_rebound  ...              sfxlevel  \
# 0        NaN     45   60  NaN           NaN  ...  attack_sound_level_s
# 1        NaN     45   70  NaN           NaN  ...  attack_sound_level_s
# 2        NaN     90   70  NaN           NaN  ...  attack_sound_level_s
# 3        NaN     68   40  NaN           NaN  ...  attack_sound_level_s
# 4        NaN     40   60  NaN           NaN  ...  attack_sound_level_s
#
#                      sfxtype  shielddamage size trip                 type  \
# 0  collision_sound_attr_none           NaN  NaN  NaN  attack_region_throw
# 1  collision_sound_attr_none           NaN  NaN  NaN  attack_region_throw
# 2  collision_sound_attr_none           NaN  NaN  NaN  attack_region_throw
# 3  collision_sound_attr_none           NaN  NaN  NaN  attack_region_throw
# 4  collision_sound_attr_none           NaN  NaN  NaN  attack_region_throw
#
#     unk   x   y   z
# 0  True NaN NaN NaN
# 1  True NaN NaN NaN
# 2  True NaN NaN NaN
# 3  True NaN NaN NaN
# 4  True NaN NaN NaN
#
# [5 rows x 43 columns]
#
# Column data types:
# character_id       object
# internal_id       float64
# move_index          int64
# throw_index         int64
# move_name          object
# absorbable         object
# angle               int64
# bkb                 int64
# bone               object
# clang_rebound      object
# collisionpart      object
# color              object
# damage            float64
# direct_hitbox      object
# disablehitlag      object
# effect             object
# facingrestrict     object
# fkb                 int64
# flinchless         object
# frames             object
# friendlyfire       object
# ground_or_air      object
# hitbits            object
# hitlag            float64
# id                  int64
# kbg                 int64
# kind               object
# notes              object
# part              float64
# reflectable        object
# rehit             float64
# sdi               float64
# setweight          object
# sfxlevel           object
# sfxtype            object
# shielddamage      float64
# size              float64
# trip              float64
# type               object
# unk                object
# x                 float64
# y                 float64
# z                 float64
# dtype: object
#
# Missing values per column:
# character_id        0
# internal_id        20
# move_index          0
# throw_index         0
# move_name           0
# absorbable        391
# angle               0
# bkb                 0
# bone              391
# clang_rebound     391
# collisionpart     391
# color             390
# damage              0
# direct_hitbox     391
# disablehitlag     391
# effect              0
# facingrestrict      0
# fkb                 0
# flinchless        391
# frames              0
# friendlyfire      391
# ground_or_air     391
# hitbits           391
# hitlag              0
# id                  0
# kbg                 0
# kind                1
# notes             381
# part              391
# reflectable       391
# rehit             391
# sdi               391
# setweight         391
# sfxlevel            0
# sfxtype             0
# shielddamage      391
# size              391
# trip              391
# type                0
# unk                 1
# x                 391
# y                 391
# z                 391
# dtype: int64

# %%
# Basic data cleaning function
def clean_dataframe(df, name):
    """
    Perform basic cleaning operations on a DataFrame.
    
    Args:
        df (pandas.DataFrame): DataFrame to clean
        name (str): Name of the DataFrame for display purposes
        
    Returns:
        pandas.DataFrame: Cleaned DataFrame
    """
    if df is None:
        return None
    
    print(f"\n\nCleaning {name} DataFrame...")
    
    # 1. Create a copy to avoid warnings
    df_clean = df.copy()
    
    # 2. Convert column names to lowercase and replace spaces with underscores
    df_clean.columns = [col.lower().replace(' ', '_') for col in df_clean.columns]
    
    # 3. Handle specific data types based on DataFrame
    if name == "characters":
        # Character-specific cleaning
        pass
    
    elif name == "moves":
        # Handle any move-specific cleaning
        # For example, handle 'autoCancel' fields if they exist
        if 'autocancel1' in df_clean.columns:
            df_clean['autocancel1'] = pd.to_numeric(df_clean['autocancel1'], errors='coerce')
            df_clean['autocancel2'] = pd.to_numeric(df_clean['autocancel2'], errors='coerce')
    
    elif name == "hitboxes":
        # Handle hitbox specific cleaning
        # Convert damage to numeric
        if 'damage' in df_clean.columns:
            df_clean['damage'] = pd.to_numeric(df_clean['damage'], errors='coerce')
        
        # Fix move types for Incineroar as mentioned in ISSUES.md
        if 'type' in df_clean.columns:
            # We need to populate this when we know the exact issue
            pass
    
    elif name == "throws":
        # Throw-specific cleaning
        pass
    
    # 4. Report the changes
    print(f"  - Standardized column names")
    print(f"  - Applied dataframe-specific cleaning")
    
    # 5. Report missing data after cleaning
    missing_data = df_clean.isna().sum()
    missing_columns = missing_data[missing_data > 0]
    if not missing_columns.empty:
        print("\n  Columns with missing values after cleaning:")
        for col, count in missing_columns.items():
            percent = (count / len(df_clean)) * 100
            print(f"  - {col}: {count} missing values ({percent:.2f}%)")
    else:
        print("\n  No missing values after cleaning")
    
    return df_clean

# Clean all dataframes
characters_clean = clean_dataframe(characters_df, "characters")
moves_clean = clean_dataframe(moves_df, "moves")
hitboxes_clean = clean_dataframe(hitboxes_df, "hitboxes")
throws_clean = clean_dataframe(throws_df, "throws")

# Display information about available characters
if characters_clean is not None:
    print("\n\nCharacters in the dataset:")
    if 'name' in characters_clean.columns:
        character_list = characters_clean['name'].sort_values().tolist()
    elif 'character_id' in characters_clean.columns:
        character_list = characters_clean['character_id'].sort_values().tolist()
    else:
        character_list = []
    
    # Print in multiple columns
    num_cols = 4
    num_chars = len(character_list)
    chars_per_col = (num_chars + num_cols - 1) // num_cols
    
    for i in range(0, chars_per_col):
        row = []
        for j in range(num_cols):
            idx = i + j * chars_per_col
            if idx < num_chars:
                row.append(character_list[idx].ljust(20))
            else:
                row.append('')
        print(''.join(row))

# Now that we have loaded and cleaned the data, we can begin analysis
print("\n\nData loading and cleaning complete. Ready for analysis!")
# Out:
# Cleaning characters DataFrame...
#   - Standardized column names
#   - Applied dataframe-specific cleaning
#
#   Columns with missing values after cleaning:
#   - hitboxes: 88 missing values (98.88%)
#   - internal_id: 5 missing values (5.62%)
#   - attr_completed: 5 missing values (5.62%)
#   - attr_id: 5 missing values (5.62%)
#   - attr_name: 5 missing values (5.62%)
#   - attr_number: 5 missing values (5.62%)
#   - attr_series: 5 missing values (5.62%)
#   - attr_value: 5 missing values (5.62%)
#   - attr_version: 5 missing values (5.62%)
#   - param_walkspeed: 8 missing values (8.99%)
#   - param_walkaddacceleration: 8 missing values (8.99%)
#   - param_walkbaseacceleration: 8 missing values (8.99%)
#   - param_groundfriction: 8 missing values (8.99%)
#   - param_dashinitialspeed: 8 missing values (8.99%)
#   - param_runaddacceleration: 8 missing values (8.99%)
#   - param_runbaseacceleration: 8 missing values (8.99%)
#   - param_runspeed: 8 missing values (8.99%)
#   - param_jumpsquat: 8 missing values (8.99%)
#   - param_jumpinitialspeed: 8 missing values (8.99%)
#   - param_jumpheight: 8 missing values (8.99%)
#   - param_hopheight: 8 missing values (8.99%)
#   - param_airjumpheight: 8 missing values (8.99%)
#   - param_aerialaddacceleration: 8 missing values (8.99%)
#   - param_aerialbaseacceleration: 8 missing values (8.99%)
#   - param_airspeed: 8 missing values (8.99%)
#   - param_airfriction: 8 missing values (8.99%)
#   - param_gravity: 8 missing values (8.99%)
#   - param_fallspeed: 8 missing values (8.99%)
#   - param_damageflytopgravity: 8 missing values (8.99%)
#   - param_damageflytopfallspeed: 8 missing values (8.99%)
#   - param_fastfallspeed: 8 missing values (8.99%)
#   - param_weight: 8 missing values (8.99%)
#   - param_nairlandinglag: 8 missing values (8.99%)
#   - param_fairlandinglag: 8 missing values (8.99%)
#   - param_bairlandinglag: 8 missing values (8.99%)
#   - param_uairlandinglag: 8 missing values (8.99%)
#   - param_dairlandinglag: 8 missing values (8.99%)
#   - param_softlandinglag: 8 missing values (8.99%)
#   - param_hardlandinglag: 8 missing values (8.99%)
#   - param_fallingframetousehardlandinglag: 8 missing values (8.99%)
#   - param_charactersizemultiplier: 8 missing values (8.99%)
#   - param_shieldsize: 8 missing values (8.99%)
#   - param_shieldbreakheight: 8 missing values (8.99%)
#   - param_guardspeedlimit: 8 missing values (8.99%)
#   - param_jostlefront: 8 missing values (8.99%)
#   - param_jostleback: 8 missing values (8.99%)
#   - param_jostleweight: 8 missing values (8.99%)
#   - param_ledgejumphspeed: 8 missing values (8.99%)
#   - param_ledgejumpheight: 8 missing values (8.99%)
#   - param_jab1tojab2endframe: 8 missing values (8.99%)
#   - param_jab2tojab3endframe: 8 missing values (8.99%)
#   - param_ftilt1toftilt2endframe: 8 missing values (8.99%)
#   - param_ftilt2toftilt3endframe: 8 missing values (8.99%)
#   - param_fsmash1tofsmash2endframe: 8 missing values (8.99%)
#   - param_hasrapidjab: 8 missing values (8.99%)
#   - param_attackinputsforrapidjab: 8 missing values (8.99%)
#   - param_rapidjabrebounddistance: 8 missing values (8.99%)
#   - param_rapidjabreboundcount: 8 missing values (8.99%)
#   - param_dtiltrebounddistance: 8 missing values (8.99%)
#   - param_dtiltreboundcount: 8 missing values (8.99%)
#   - param_fsmashmaxdamagemultiplier: 8 missing values (8.99%)
#   - param_usmashmaxdamagemultiplier: 8 missing values (8.99%)
#   - param_dsmashmaxdamagemultiplier: 8 missing values (8.99%)
#   - param_fsmashmaxchargeframes: 8 missing values (8.99%)
#   - param_usmashmaxchargeframes: 8 missing values (8.99%)
#   - param_dsmashmaxchargeframes: 8 missing values (8.99%)
#   - param_fsmashmaxchargeheldframes: 8 missing values (8.99%)
#   - param_usmashmaxchargeheldframes: 8 missing values (8.99%)
#   - param_dsmashmaxchargeheldframes: 8 missing values (8.99%)
#   - param_jumpcount: 8 missing values (8.99%)
#   - param_hascrawl: 8 missing values (8.99%)
#   - param_haswalljump: 8 missing values (8.99%)
#   - param_haswallcling: 8 missing values (8.99%)
#   - param_haszair: 8 missing values (8.99%)
#   - param_footstooljumpspeedmultiplier: 8 missing values (8.99%)
#   - param_footstoolhopspeedmultiplier: 8 missing values (8.99%)
#   - param_airbornefootstoolendlag: 8 missing values (8.99%)
#   - param_walljumphspeed: 8 missing values (8.99%)
#   - param_walljumpvspeed: 8 missing values (8.99%)
#   - param_finalsmashmeterdamagemultiplier: 8 missing values (8.99%)
#   - param_finalsmashmeterkbmultiplier: 8 missing values (8.99%)
#   - map_value: 1 missing values (1.12%)
#   - map_number: 1 missing values (1.12%)
#   - map_id: 1 missing values (1.12%)
#   - map_series: 1 missing values (1.12%)
#   - map_completed: 1 missing values (1.12%)
#   - map_version: 1 missing values (1.12%)
#
#
# Cleaning moves DataFrame...
#   - Standardized column names
#   - Applied dataframe-specific cleaning
#
#   Columns with missing values after cleaning:
#   - internal_id: 202 missing values (5.58%)
#   - complete: 3595 missing values (99.28%)
#   - grabs: 3329 missing values (91.94%)
#   - hurtboxes: 2647 missing values (73.10%)
#   - notes: 3571 missing values (98.62%)
#   - type: 3620 missing values (99.97%)
#
#
# Cleaning hitboxes DataFrame...
#   - Standardized column names
#   - Applied dataframe-specific cleaning
#
#   Columns with missing values after cleaning:
#   - internal_id: 478 missing values (4.19%)
#   - absorbable: 74 missing values (0.65%)
#   - angle: 61 missing values (0.53%)
#   - bkb: 61 missing values (0.53%)
#   - bone: 60 missing values (0.53%)
#   - clang_rebound: 74 missing values (0.65%)
#   - collisionpart: 74 missing values (0.65%)
#   - color: 105 missing values (0.92%)
#   - damage: 63 missing values (0.55%)
#   - direct_hitbox: 183 missing values (1.60%)
#   - direct_indirect: 11299 missing values (99.04%)
#   - disablehitlag: 74 missing values (0.65%)
#   - effect: 61 missing values (0.53%)
#   - facingrestrict: 61 missing values (0.53%)
#   - fkb: 61 missing values (0.53%)
#   - flinchless: 74 missing values (0.65%)
#   - friendlyfire: 74 missing values (0.65%)
#   - ground_or_air: 60 missing values (0.53%)
#   - hitbits: 74 missing values (0.65%)
#   - hitlag: 61 missing values (0.53%)
#   - id: 47 missing values (0.41%)
#   - kbg: 61 missing values (0.53%)
#   - kind: 11395 missing values (99.89%)
#   - notes: 10807 missing values (94.73%)
#   - part: 74 missing values (0.65%)
#   - reflectable: 74 missing values (0.65%)
#   - rehit: 74 missing values (0.65%)
#   - sdi: 74 missing values (0.65%)
#   - setweight: 74 missing values (0.65%)
#   - sfxlevel: 61 missing values (0.53%)
#   - sfxtype: 61 missing values (0.53%)
#   - shielddamage: 74 missing values (0.65%)
#   - size: 60 missing values (0.53%)
#   - status: 11394 missing values (99.88%)
#   - trip: 74 missing values (0.65%)
#   - type: 61 missing values (0.53%)
#   - unk: 11395 missing values (99.89%)
#   - x: 60 missing values (0.53%)
#   - x2: 4354 missing values (38.17%)
#   - y: 60 missing values (0.53%)
#   - y2: 4354 missing values (38.17%)
#   - z: 60 missing values (0.53%)
#   - z2: 4355 missing values (38.17%)
#
#
# Cleaning throws DataFrame...
#   - Standardized column names
#   - Applied dataframe-specific cleaning
#
#   Columns with missing values after cleaning:
#   - internal_id: 20 missing values (5.10%)
#   - absorbable: 391 missing values (99.74%)
#   - bone: 391 missing values (99.74%)
#   - clang_rebound: 391 missing values (99.74%)
#   - collisionpart: 391 missing values (99.74%)
#   - color: 390 missing values (99.49%)
#   - direct_hitbox: 391 missing values (99.74%)
#   - disablehitlag: 391 missing values (99.74%)
#   - flinchless: 391 missing values (99.74%)
#   - friendlyfire: 391 missing values (99.74%)
#   - ground_or_air: 391 missing values (99.74%)
#   - hitbits: 391 missing values (99.74%)
#   - kind: 1 missing values (0.26%)
#   - notes: 381 missing values (97.19%)
#   - part: 391 missing values (99.74%)
#   - reflectable: 391 missing values (99.74%)
#   - rehit: 391 missing values (99.74%)
#   - sdi: 391 missing values (99.74%)
#   - setweight: 391 missing values (99.74%)
#   - shielddamage: 391 missing values (99.74%)
#   - size: 391 missing values (99.74%)
#   - trip: 391 missing values (99.74%)
#   - unk: 1 missing values (0.26%)
#   - x: 391 missing values (99.74%)
#   - y: 391 missing values (99.74%)
#   - z: 391 missing values (99.74%)
#
#
# Characters in the dataset:
# Banjo & Kazooie     Ike                 Mii Brawler         Samus
# Bayonetta           Incineroar          Mii Gunner          Sephiroth
# Bowser              Inkling             Mii Swordfighter    Sheik
# Bowser Jr.          Isabelle            Min Min             Shulk
# Byleth              Ivysaur             Mr. Game & Watch    Simon
# Captain Falcon      Jigglypuff          Mythra              Snake
# Charizard           Joker               Ness                Sonic
# Chrom               Kazuya              Olimar              Sora
# Cloud               Ken                 Pac-Man             Squirtle
# Corrin              King Dedede         Palutena            Steve
# Daisy               King K. Rool        Peach               Terry
# Dark Pit            Kirby               Pichu               Toon Link
# Dark Samus          Link                Pikachu             Villager
# Diddy Kong          Little Mac          Piranha Plant       Wario
# Donkey Kong         Lucario             Pit                 Wii Fit Trainer
# Dr. Mario           Lucas               Pyra                Wolf
# Duck Hunt           Lucina              R.O.B.              Yoshi
# Falco               Luigi               Richter             Young Link
# Fox                 Mario               Ridley              Zelda
# Ganondorf           Marth               Robin               Zero Suit Samus
# Greninja            Mega Man            Rosalina & Luma
# Hero                Meta Knight         Roy
# Ice Climbers        Mewtwo              Ryu
#
#
# Data loading and cleaning complete. Ready for analysis!
